# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("./daily_lcd_good.csv")
pd.to_numeric(df['DailyPeakWindSpeed'])
df
# Out:
#      Unnamed: 0  DailyAverageDryBulbTemperature  DailyAverageStationPreure  \
# 0            53                              36                      29.30
# 1           102                              36                      29.36
# 2           142                              31                      29.36
# 3           181                              33                      29.37
# 4           213                              31                      29.44
# ..          ...                             ...                        ...
# 467       15795                              57                      29.01
# 468       15825                              47                      29.33
# 469       15850                              53                      29.36
# 470       15877                              50                      29.44
# 471       15902                              45                      29.55
#
#      DailyAverageWindSpeed  DailyCoolingDegreeDay  \
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                                      int64
# DailyAverageDryBulbTemperature                  int64
# DailyAverageStationPreure                     float64
# DailyAverageWindSpeed                         float64
# DailyCoolingDegreeDay                           int64
# DailyDepartureFromNormalAverageTemperature    float64
# DailyHeatingDegreeDay                           int64
# DailyMaximumDryBulbTemperature                  int64
# DailyMinimumDryBulbTemperature                  int64
# DailyPeakWindDirection                          int64
# DailyPeakWindSpeed                              int64
# DailyPrecipitation                            float64
# DailySnowDepth                                  int64
# DailySnowfall                                   int64
# DailySutainedWindDirection                      int64
# DailySutainedWindSpeed                          int64
# DailyWeather                                   object
# ...

# %%
X = df.iloc[:-1, 1:-2]
y = df['Tommrow DailyAvegerageDryBulb']
y = y.iloc[:-1]
X.head(3)
# Out:
#    DailyAverageDryBulbTemperature  DailyAverageStationPreure  \
# 0                              36                      29.30
# 1                              36                      29.36
# 2                              31                      29.36
#
#    DailyAverageWindSpeed  DailyCoolingDegreeDay  \
# 0                   11.8                      0
# 1                    3.2                      0
# 2                    6.0                      0
#
#    DailyDepartureFromNormalAverageTemperature  DailyHeatingDegreeDay  \
# 0                                         7.4                     29
# 1                                         7.5                     29
# 2                                         2.6                     34
#
#    DailyMaximumDryBulbTemperature  DailyMinimumDryBulbTemperature  \
# 0                              43                              28
# 1                              37                              34
# ...

# %%
df = pd.concat([X, y], axis=1)
df
# Out:
#      DailyAverageDryBulbTemperature  DailyAverageStationPreure  \
# 0                                36                      29.30
# 1                                36                      29.36
# 2                                31                      29.36
# 3                                33                      29.37
# 4                                31                      29.44
# ..                              ...                        ...
# 466                              59                      29.29
# 467                              57                      29.01
# 468                              47                      29.33
# 469                              53                      29.36
# 470                              50                      29.44
#
#      DailyAverageWindSpeed  DailyCoolingDegreeDay  \
# 0                     11.8                      0
# 1                      3.2                      0
# 2                      6.0                      0
# ...

# %%
(train, test) = train_test_split(df, train_size=0.8, shuffle=True)

# %%
X_train = train.iloc[:-1, :-2]
y_train = train['Tommrow DailyAvegerageDryBulb']
X_test = test.iloc[:-1, :-2]
y_test = test['Tommrow DailyAvegerageDryBulb']
y_test = y_test.iloc[:-1]
y_train = y_train.iloc[:-1]
X_train
# Out:
#      DailyAverageDryBulbTemperature  DailyAverageStationPreure  \
# 99                               59                      28.95
# 360                              54                      29.09
# 55                               37                      29.68
# 264                              57                      29.39
# 85                               58                      29.32
# ..                              ...                        ...
# 95                               67                      29.31
# 413                              24                      29.56
# 336                              47                      29.34
# 127                              46                      29.44
# 295                              51                      29.39
#
#      DailyAverageWindSpeed  DailyCoolingDegreeDay  \
# 99                     9.0                      0
# 360                   11.1                      0
# 55                     4.0                      0
# ...

# %%
# Creating a baseline using only the average temperature from the previous day
Xb_train = X_train['DailyAverageDryBulbTemperature']
yb_train = y_train
Xb_test = X_test['DailyAverageDryBulbTemperature']
yb_test = y_test
lrb = LinearRegression()
lrb.fit(Xb_train.values.reshape(-1, 1), yb_train)
lrb.score(Xb_test.values.reshape(-1, 1), yb_test)
# Out:
# 0.8837828606301995

# %%
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(X_test, y_test)
# Out:
# 0.927279108195419
