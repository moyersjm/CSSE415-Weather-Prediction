# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV, cross_validate
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score
import numpy as np
import time

# %%
df = pd.read_hdf('./Big_Data/big_data.h5')
df.head()
# Out:
#    mean_temperature_14  mean_temperature_13  mean_temperature_12  \
# 2           301.820000           301.871458           301.850625
# 6           299.885833           299.978333           298.984167
# 7           299.733542           298.048542           298.555208
# 8           302.018958           301.820000           301.871458
# 9           300.032500           298.790000           299.420000
#
#    mean_temperature_11  mean_temperature_10  mean_temperature_9  \
# 2           300.702292           299.662292          299.835625
# 6           299.562500           300.921250          300.137500
# 7           297.823958           298.996667          298.486042
# 8           301.850625           300.702292          299.662292
# 9           298.792500           298.235417          298.437083
#
#    mean_temperature_8  mean_temperature_7  mean_temperature_6  \
# 2          298.917917          299.906042          301.140417
# 6          299.828750          299.030000          298.639167
# 7          297.319375          298.311250          298.098125
# 8          299.835625          298.917917          299.906042
# 9          297.966667          298.190000          297.607500
#
#    mean_temperature_5  ...  wind_speed_0_2  wind_speed_0_3  wind_speed_0_4  \
# 2          299.718333  ...             9.0             9.0             9.0
# 6          297.822917  ...             0.0             0.0             0.0
# 7          298.106667  ...             2.0             2.0             2.0
# 8          301.140417  ...             5.0             3.0             3.0
# 9          298.117500  ...             6.0             6.0             6.0
#
#    wind_speed_0_5  wind_speed_0_6  wind_speed_0_7  wind_speed_0_8  \
# 2             9.0             9.0             9.0             9.0
# 6             0.0             1.0             3.0             2.0
# 7             2.0             1.0             1.0             3.0
# 8             7.0             7.0             7.0             6.0
# 9             6.0             3.0             3.0             3.0
#
#    wind_speed_0_9  wind_speed_0_10  wind_speed_0_11
# 2             9.0              9.0              9.0
# 6             0.0              0.0              1.0
# 7             2.0              2.0              6.0
# 8             5.0              8.0              6.0
# 9             3.0              3.0              3.0
#
# [5 rows x 135 columns]

# %%
df = (df-df.mean())/df.std()
df_train, df_test = train_test_split(df,test_size=0.1,random_state=1)

# %%
try:
    n_pred = int(df.columns[0][-2:])
except:
    n_pred = int(df.columns[0][-1])
n_pred
# Out:
# 14

# %%
df_train, df_test = train_test_split(df,test_size=0.1,random_state=1)
X_train = df_train.iloc[:,n_pred:].reset_index(drop=True)
y_train = df_train.iloc[:,n_pred:n_pred+n_pred].reset_index(drop=True)

# %%
y_train
# Out:
#       day_of_year  temperature_0_12  temperature_0_13  temperature_0_14  \
# 0       -0.665512          0.385089          0.520621          0.586681
# 1       -1.464657         -1.339800         -1.305035         -1.373572
# 2        1.684354         -1.581816         -1.457869         -1.524250
# 3        0.523691          1.579244          1.694257          1.829482
# 4        0.228769          0.626905          0.791296          0.812023
# ...           ...               ...               ...               ...
# 9666    -1.122167         -0.278330         -0.000995         -0.328103
# 9667    -0.246913          1.048508          1.042237          1.240099
# 9668    -1.027030         -1.376952         -1.268001         -1.242888
# 9669    -0.941408         -0.250334         -0.157741         -0.102152
# 9670     1.284782          0.503178         -0.074021         -0.226170
#
#       temperature_0_15  temperature_0_16  temperature_0_17  temperature_0_18  \
# 0             0.662559          0.786502          0.706946          0.717481
# 1            -1.337871         -1.459787         -1.344042         -1.473975
# 2            -1.590294         -1.626541         -1.681868         -1.706179
# 3             1.960698          1.975714          2.261796          2.319491
# 4             0.559682          0.730741          0.745535          0.721566
# ...                ...               ...               ...               ...
# 9666         -0.375951         -0.402710         -0.354592         -0.452657
# 9667          1.052001          1.182906          0.415483          0.488122
# 9668         -1.298927         -1.365399         -1.409251         -1.619878
# 9669         -0.269439         -0.090255         -0.062092          0.039326
# 9670         -0.433069         -0.549379         -0.370141         -0.404510
#
#       temperature_0_19  temperature_0_20  temperature_0_21  temperature_0_22  \
# 0             0.653668          0.493678          0.555044          0.632641
# 1            -1.450463         -1.345558         -1.332485         -1.336672
# 2            -1.827102         -1.803692         -1.822699         -1.846572
# 3             2.105896          2.120012          2.137793          1.844526
# 4             0.490644          0.465784          0.469419          0.345980
# ...                ...               ...               ...               ...
# 9666         -0.222326         -0.097717         -0.199364         -0.124787
# 9667          0.570434          0.799428          0.867068          0.945913
# 9668         -1.586301         -1.592465         -1.573896         -1.563143
# 9669         -0.143166         -0.051292         -0.030225          0.008318
# 9670         -0.319820         -0.278092         -0.317051         -0.326263
#
#       temperature_0_23  temperature_0_0
# 0            -0.540911        -0.544776
# 1            -1.234626        -1.240113
# 2            -1.817284        -1.803439
# 3             1.219085         1.219335
# 4             0.425281         0.545167
# ...                ...              ...
# 9666          0.030989         0.028461
# 9667          1.087936         1.087879
# 9668         -1.410230        -1.416127
# 9669          0.137512         0.285109
# 9670         -0.268013        -0.358454
#
# [9671 rows x 14 columns]
