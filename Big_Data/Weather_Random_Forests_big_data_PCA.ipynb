# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, GridSearchCV, cross_validate
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score
import numpy as np
import time
from sklearn.decomposition import PCA

# %%
df = pd.read_hdf('Global_Weather_Data/big_data.h5')
df.head()
# Out:
#    mean_temperature_7  mean_temperature_6  mean_temperature_5  \
# 3          299.906042          301.140417          299.718333
# 6          296.587500          296.475000          297.020000
# 7          298.190000          297.607500          298.117500
# 8          298.190000          297.607500          298.117500
# 9          298.917917          299.906042          301.140417
#
#    mean_temperature_4  mean_temperature_3  mean_temperature_2  \
# 3          299.908125          300.634792          302.856458
# 6          296.770833          297.652500          297.247500
# 7          298.035417          298.867500          298.677500
# 8          298.035417          298.867500          298.677500
# 9          299.718333          299.908125          300.634792
#
#    mean_temperature_1  day_of_year  altitude   latitude  ...  wind_speed_0_2  \
# 3          302.795433          275      1148  29.558050  ...             9.0
# 6          301.199792          276      2474  31.769039  ...             2.0
# 7          300.139167          276        46  33.005859  ...             6.0
# 8          300.197708          276        33  32.815559  ...             6.0
# 9          302.856458          276      1148  29.558050  ...             5.0
#
#    wind_speed_0_3  wind_speed_0_4  wind_speed_0_5  wind_speed_0_6  \
# 3             9.0             9.0             9.0             9.0
# 6             2.0             2.0             2.0             0.0
# 7             6.0             6.0             6.0             3.0
# 8             6.0             6.0             6.0             3.0
# 9             3.0             3.0             7.0             7.0
#
#    wind_speed_0_7  wind_speed_0_8  wind_speed_0_9  wind_speed_0_10  \
# 3             9.0             9.0             9.0              9.0
# 6             0.0             0.0             0.0              0.0
# 7             3.0             3.0             3.0              3.0
# 8             3.0             3.0             3.0              3.0
# 9             7.0             6.0             5.0              8.0
#
#    wind_speed_0_11
# 3              9.0
# 6              0.0
# 7              3.0
# 8              3.0
# 9              6.0
#
# [5 rows x 130 columns]

# %%
try:
    n_pred = int(df.columns[0][-2:])
except:
    n_pred = int(df.columns[0][-1])

# %%
df_mean = df.mean()
df_std = df.std()
df = (df-df.mean())/df.std()
df_train, df_test = train_test_split(df,test_size=0.1,random_state=1)
X_train = df_train.iloc[:,n_pred:].reset_index(drop=True)
# X_train_mean = X_train.mean()
# X_train_std = X_train.std()
# X_train = (X_train-X_train.mean())/X_train.std()

y_train = df_train.iloc[:,:n_pred].reset_index(drop=True)

X_test = df_test.iloc[:,n_pred:].reset_index(drop=True)
# X_test_mean = X_test.mean()
# X_test_std = X_test.std()
# X_test = (X_test-X_test.mean())/X_test.std()

y_test = df_test.iloc[:,:n_pred].reset_index(drop=True)

# %%
n_comp = 81

pca = PCA(n_components=n_comp)
pca.fit(X_train)
X_train_orig = X_train.copy()
X_test_orig = X_test.copy()
X_train = pca.transform(X_train)
X_test = pca.transform(X_test)

# %%
# grid = {'n_estimators':np.arange(10,301,10), 'max_depth':np.arange(1,30,1),'learning_rate':[1e-3,1e-2,1e-1]}
# grid = {'n_estimators':np.arange(10,201,10), 'max_depth':np.arange(1,20,1),'learning_rate':[1e-1,1e-2,1e-3]}
# grid = {'n_estimators':np.arange(500,1501,100), 'max_depth':np.arange(1,10,2),'learning_rate':np.arange(0.05,0.16,0.02)}
# grid = {'n_estimators':[500], 'max_depth':np.arange(6,9,1),'learning_rate':[0.1]}
# grid = {'n_estimators':np.arange(400,1001,100), 'max_depth':np.arange(5,11,1),'learning_rate':[0.1]}
grid = {'n_estimators':[500], 'max_depth':[7],'learning_rate':[0.1]}
gbt = GradientBoostingRegressor()
gbtCV = GridSearchCV(gbt,param_grid=grid,return_train_score=True,n_jobs=-1,verbose=1)

# %%
for i in range(n_pred,0,-1):
    start = time.time()
    idx = n_pred-i
    gbtCV.fit(X_train,y_train.iloc[:,idx])
    score = gbtCV.best_estimator_.score(X_test,y_test.iloc[:,idx])
    print('Forecasting mean temperature',i,'days ahead with 24 hours of history:')
    print('\tBest depth:\t\t', gbtCV.best_params_['max_depth'], '\n\tBest # estimators:\t', gbtCV.best_params_['n_estimators'],
          '\n\tBest learning rate:\t', gbtCV.best_params_['learning_rate'], '\n\tTraining R^2\t =',gbtCV.best_score_)
    print('\n\tValidation R^2\t=',score)
    
    baseline_score = r2_score(y_test.iloc[:,idx],X_test_orig.iloc[:,1:25].mean(axis=1))
    print('\tBaseline\t=',baseline_score)
    if score > baseline_score:
        print('\tGood!')
    else:
        print('\tBad!')
    end = time.time()
    print('\nTotal minutes =',(end-start)/60)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Forecasting mean temperature 7 days ahead with 24 hours of history:
# 	Best depth:		 7
# 	Best # estimators:	 500
# 	Best learning rate:	 0.1
# 	Training R^2	 = 0.8359915762684796
#
# 	Validation R^2	= 0.8392689788871186
# 	Baseline	= 0.7737052927346195
# 	Good!
#
# Total minutes = 6.923977967103323
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Forecasting mean temperature 6 days ahead with 24 hours of history:
# 	Best depth:		 7
# 	Best # estimators:	 500
# 	Best learning rate:	 0.1
# 	Training R^2	 = 0.8420456870831512
#
# 	Validation R^2	= 0.8360426392911923
# 	Baseline	= 0.7859239331265391
# 	Good!
#
# Total minutes = 6.9259308218956
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Forecasting mean temperature 5 days ahead with 24 hours of history:
# 	Best depth:		 7
# 	Best # estimators:	 500
# 	Best learning rate:	 0.1
# 	Training R^2	 = 0.851759927262183
#
# 	Validation R^2	= 0.8513596980313405
# 	Baseline	= 0.7897306522208862
# 	Good!
#
# Total minutes = 6.863487652937571
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Forecasting mean temperature 4 days ahead with 24 hours of history:
# 	Best depth:		 7
# 	Best # estimators:	 500
# 	Best learning rate:	 0.1
# 	Training R^2	 = 0.8604631875278695
#
# 	Validation R^2	= 0.8532769337377071
# 	Baseline	= 0.802324578650554
# 	Good!
#
# Total minutes = 6.83660302956899
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# Forecasting mean temperature 3 days ahead with 24 hours of history:
# 	Best depth:		 7
# 	Best # estimators:	 500
# 	Best learning rate:	 0.1
# 	Training R^2	 = 0.8754092656672439
#
# 	Validation R^2	= 0.8673687763857999
# 	Baseline	= 0.8211670140514602
# 	Good!
#
# Total minutes = 6.839250342051188
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_3225432/2034103699.py in <module>
#       2     start = time.time()
#       3     idx = n_pred-i
# ----> 4     gbtCV.fit(X_train,y_train.iloc[:,idx])
#       5     score = gbtCV.best_estimator_.score(X_test,y_test.iloc[:,idx])
#       6     print('Forecasting mean temperature',i,'days ahead with 24 hours of history:')
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     924             refit_start_time = time.time()
#     925             if y is not None:
# --> 926                 self.best_estimator_.fit(X, y, **fit_params)
#     927             else:
#     928                 self.best_estimator_.fit(X, **fit_params)
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/_gb.py in fit(self, X, y, sample_weight, monitor)
#     594             sample_weight_val,
#     595             begin_at_stage,
# --> 596             monitor,
#     597         )
#     598
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/_gb.py in _fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     670                 random_state,
#     671                 X_csc,
# --> 672                 X_csr,
#     673             )
#     674
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/_gb.py in _fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_csc, X_csr)
#     244
#     245             X = X_csr if X_csr is not None else X
# --> 246             tree.fit(X, residual, sample_weight=sample_weight, check_input=False)
#     247
#     248             # update tree leaves
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#    1318             sample_weight=sample_weight,
#    1319             check_input=check_input,
# -> 1320             X_idx_sorted=X_idx_sorted,
#    1321         )
#    1322         return self
#
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/tree/_classes.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     418             )
#     419
# --> 420         builder.build(self.tree_, X, y, sample_weight)
#     421
#     422         if self.n_outputs_ == 1 and is_classifier(self):
#
# KeyboardInterrupt:

# %%
features = pd.DataFrame()
features['names'] = gbtCV.best_estimator_.feature_names_in_
features['importance'] = gbtCV.best_estimator_.feature_importances_
features.sort_values(by='importance',ascending=False)

# %%
gbtCV.best_estimator_.predict(X_test.iloc[0:1,:])

# %%
# df.mean()

# %%
# df.std()

# %%
# y_test.iloc[0:1,:]

# %%
fun = features.sort_values(by='importance',ascending=False).reset_index(drop=True)
for i in range(features.shape[0]):
    print(fun.names[i],fun.importance[i])
